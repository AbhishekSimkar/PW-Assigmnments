# %%
'1. What are the key features of the wine quality data set? Discuss the importance of each feature in predicting the quality of wine.'
# Out:
# '1. What are the key features of the wine quality data set? Discuss the importance of each feature in predicting the quality of wine.'

# %%
'''The key features are fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates.
Alcohol, Sulphates abd citrc acid increasesthe quality of drink whereas others have negative effect on the quality.'''
# Out:
# 'The key features are fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates.\nAlcohol, Sulphates abd citrc acid increasesthe quality of drink whereas others have negative effect on the quality.'

# %%
'2. How did you handle missing data in the wine quality data set during the feature engineering process? Discuss the advantages and disadvantages of different imputation techniques.'
# Out:
# '2. How did you handle missing data in the wine quality data set during the feature engineering process? Discuss the advantages and disadvantages of different imputation techniques.'

# %%
'''By using median or mode imputation method for handling the missing value in the wine quality data set during feature engineering.
Advantages: We can fill missing values, values may not too much differ from the real one, we can assume value more precisely.
Disadvanges: We may fill wrong value, In case of outlier it may differ by huge value.'''
# Out:
# 'By using median or mode imputation method for handling the missing value in the wine quality data set during feature engineering.\nAdvantages: We can fill missing values, values may not too much differ from the real one, we can assume value more precisely.\nDisadvanges: We may fill wrong value, In case of outlier it may differ by huge value.'

# %%
'''3. What are the key factors that affect students' performance in exams? How would you go about analyzing these factors using statistical techniques?'''
# Out:
# "3. What are the key factors that affect students' performance in exams? How would you go about analyzing these factors using statistical techniques?"

# %%
'''1) Female student tend to perform well than male students.
2) Standard Lunch help students perform well in exams.
3) Students of group A and group B tends to perform poorly in exam.'''
# Out:
# '1) Female student tend to perform well than male students.\n2) Standard Lunch help students perform well in exams.\n3) Students of group A and group B tends to perform poorly in exam.'

# %%
'''4. Describe the process of feature engineering in the context of the student performance data set. How did you select and transform the variables for your model?'''
# Out:
# '4. Describe the process of feature engineering in the context of the student performance data set. How did you select and transform the variables for your model?'

# %%
'''Using feature engineering we will perform following:
Check Missing values.
Check Duplicates.
Check data type.
Check the number of unique values of each column.
Check statistics of data set.
Check various categories present in the different categorical column.'''
# Out:
# 'Using feature engineering we will perform following:\nCheck Missing values.\nCheck Duplicates.\nCheck data type.\nCheck the number of unique values of each column.\nCheck statistics of data set.\nCheck various categories present in the different categorical column.'

# %%
'''5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to these features to improve normality?'''
# Out:
# '5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to these features to improve normality?'

# %%
import pandas as pd
df=pd.read_csv('winequality-red.csv')
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
sns.histplot(data=df['fixed acidity'],bins=30,kde=True)
# Out:
# <AxesSubplot: xlabel='fixed acidity', ylabel='Count'>

# %%
sns.histplot(data=df['volatile acidity'],bins=30,kde=True)
# Out:
# <AxesSubplot: xlabel='volatile acidity', ylabel='Count'>

# %%
sns.histplot(data=df['residual sugar'],bins=30,kde=True)
# Out:
# <AxesSubplot: xlabel='residual sugar', ylabel='Count'>

# %%
sns.histplot(data=df['free sulfur dioxide'],bins=30,kde=True)
# Out:
# <AxesSubplot: xlabel='free sulfur dioxide', ylabel='Count'>

# %%
sns.histplot(data=df['total sulfur dioxide'],bins=30,kde=True)
# Out:
# <AxesSubplot: xlabel='total sulfur dioxide', ylabel='Count'>

# %%
sns.histplot(data=df['density'],bins=30,kde=True)
# Out:
# <AxesSubplot: xlabel='density', ylabel='Count'>

# %%
sns.histplot(data=df['pH'],bins=30,kde=True)
# Out:
# <AxesSubplot: xlabel='pH', ylabel='Count'>

# %%
sns.histplot(data=df['sulphates'],bins=30,kde=True)
# Out:
# <AxesSubplot: xlabel='sulphates', ylabel='Count'>

# %%
sns.histplot(data=df['chlorides'],bins=30,kde=True)
# Out:
# <AxesSubplot: xlabel='chlorides', ylabel='Count'>

# %%
sns.histplot(data=df['alcohol'],bins=30,kde=True)
# Out:
# <AxesSubplot: xlabel='alcohol', ylabel='Count'>

# %%
'''residual sugar, total sulphur dioxide, density and alcohol have non-normal distribution. We can handle it by Upsampling or downsampling of data.'''
# Out:
# 'residual sugar, total sulphur dioxide, density and alcohol have non-normal distribution. We can handle it by Upsampling or downsampling of data.'

# %%
'''6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of features. What is the minimum number of principal components required to explain 90% of the variance in the data?'''
# Out:
# '6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of features. What is the minimum number of principal components required to explain 90% of the variance in the data?'
